# %%
from math import factorial


def combinations(n, k):
    return factorial(n)/(factorial(k)*factorial(n-k))

def formula_bernuli(n, k, p):
    return combinations(n, k)*p**k*(1-p)**(n-k)

# %% [markdown]
# 1. Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.

# %%
formula_bernuli(100, 85, 0.8)
# Out:
# 0.048061793700746355

# %% [markdown]
# 2. Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек.

# %% [markdown]
# Какова вероятность, что ни одна из них не перегорит в первый день?

# %%
formula_bernuli(5000, 0, 0.0004)
# Out:
# 0.13528114551440706

# %% [markdown]
#  Какова вероятность, что перегорят ровно две?

# %%
formula_bernuli(5000, 2, 0.0004)
# Out:
# 0.2707247150266753

# %% [markdown]
# 3. Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?

# %%
formula_bernuli(144, 77, 0.5)
# Out:
# 0.04700364807160971

# %% [markdown]
# 4. В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча.

# %% [markdown]
# Какова вероятность того, что все мячи белые?

# %%
combinations(7, 2)/combinations(10, 2)*combinations(9, 2)/combinations(11, 2)
# Out:
# 0.3054545454545455

# %% [markdown]
# Какова вероятность того, что ровно два мяча белые?

# %%
# из 1 урны 2 белых
p1 = combinations(7, 2)/combinations(10, 2)*combinations(3, 2)/combinations(10, 3)

# %%
# из 1 урны 1 белый
p21 = combinations(7, 1)/combinations(10, 1)*combinations(3, 1)/combinations(10, 1)

# %%
# из 2 урны 2 белых
p22 = combinations(9, 1)/combinations(11, 1)*combinations(2, 1)/combinations(11, 1)

# %%
p21*p22
# Out:
# 0.0312396694214876

# %% [markdown]
# Какова вероятность того, что хотя бы один мяч белый?

# %%
1 - combinations(3, 2)/combinations(10, 2)*combinations(3, 2)/combinations(11, 2)
# Out:
# 0.9963636363636363
