# %% [markdown]
# 1) Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks):
# zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110],
# ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832].
# Найдите ковариацию этих двух величин с помощью элементарных действий, а затем с помощью функции cov из numpy
# Полученные значения должны быть равны.
# Найдите коэффициент корреляции Пирсона с помощью ковариации и среднеквадратичных отклонений двух признаков,
# а затем с использованием функций из библиотек numpy и pandas.

# %%
from math import sqrt
import numpy as np


def cov(x, y):
    x_avg = sum(x)/len(x)
    y_avg = sum(y)/len(y)
    value = 0
    for i in range(len(x)):
        value += x[i]*y[i]
    value = value/len(x) - x_avg*y_avg
    return value

def disp(x):
    x_avg = sum(x)/len(x)
    value = 0
    for i in x:
        value += (i - x_avg)**2
    return value

zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110]
ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]
print(cov(zp, ks))
print(np.cov(zp, ks))
print(np.cov(zp, ks, ddof=0))
print(cov(zp, ks)/sqrt(disp(zp)*disp(ks)))
# Out:
# 9157.839999999997
# [[ 3882.93333333 10175.37777778]
#  [10175.37777778 33854.32222222]]
# [[ 3494.64  9157.84]
#  [ 9157.84 30468.89]]
# 0.08874900920739158

# %% [markdown]
# 2) Измерены значения IQ выборки студентов,
# обучающихся в местных технических вузах:
# 131, 125, 115, 122, 131, 115, 107, 99, 125, 111.
# Известно, что в генеральной совокупности IQ распределен нормально.
# Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
def disp(x, x_avg):
    value = 0
    for i in x:
        value += (i - x_avg)**2
    return value


iq = [131, 125, 115, 122, 131, 115, 107, 99, 125, 111]
iq_avg = sum(iq)/len(iq)
min = iq_avg - 2.26*sqrt(disp(iq, iq_avg)/(len(iq)-1))/len(iq)**0.5
max = iq_avg + 2.26*sqrt(disp(iq, iq_avg)/(len(iq)-1))/len(iq)**0.5
print(min, ' ', max)
# Out:
# 110.56327742907362   125.63672257092637

# %% [markdown]
# 3) Известно, что рост футболистов в сборной распределен нормально
# с дисперсией генеральной совокупности, равной 25 кв.см. Объем выборки равен 27,
# среднее выборочное составляет 174.2. Найдите доверительный интервал для математического
# ожидания с надежностью 0.95.

# %%
disp = 25
n = 27
avg = 174.2
min = avg - 1.96*sqrt(disp)/n**0.5
max = avg + 1.96*sqrt(disp)/n**0.5
print(min, ' ', max)
# Out:
# 172.31398912064722   176.08601087935276
